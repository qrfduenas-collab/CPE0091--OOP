# %% [markdown]
# <a href="https://colab.research.google.com/github/qrfduenas-collab/CPE0091--OOP/blob/main/PRELIM_PRACTICAL_DUENAS_Q_29_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Develop a python scripts that:
#
# Calculate total marks and percentage
# Assign grade for each subject based on marks:
# 90-100: A+
#
# 80-89: A
#
# 70-79: B+
#
# 60-69: B
#
# 50-59: C
#
# 40-49: D
#
# Below 40: F (Fail)
#
# Determine overall result (Pass/Fail)
#
#
# Performance Remarks:
#
#
# Percentage ≥ 90: "Outstanding"
#
# Percentage ≥ 80: "Excellent"
#
# Percentage ≥ 70: "Very Good"
#
# Percentage ≥ 60: "Good"
#
# Percentage ≥ 40: "Satisfactory"
#
# Below 40: "Needs Improvement"

# %%
print("Input your Grades:")
print("     ")

Courses = ["Objected Oriented Programming", "GEE", "Mathematics In Modern World", "Calculus", "Physics"]
marks = []
for sub in Courses:
    score = float(input(f"Enter marks for {sub}: "))
    marks.append(score)
finalmarks = sum(marks)
percentage = finalmarks / len(Courses)

result = " Passed^-^" if percentage >= 40 else " Failed>: 99"

if percentage >= 90:
    remarks = "Outstanding^__^"
elif percentage >= 80:
    remarks = "Excellent^^"
elif percentage >= 70:
    remarks = "Very Good<3"
elif percentage >= 60:
    remarks = "Good"
elif percentage >= 40:
    remarks = "Satisfactory"
else:
    remarks = "Needs Improvement<:"

print("     ")
print("Grades:")
print("     ")

for i in range(len(Courses)):

    g = marks[i]
    if g >= 90: grade = "A+"
    elif g >= 80: grade = "A"
    elif g >= 70: grade = "B+"
    elif g >= 60: grade = "B"
    elif g >= 50: grade = "C"
    elif g >= 40: grade = "D"
    else: grade = "F"

    print(f"{Courses[i]}: {m} (Grade: {grade})")

print("     ")
print("Overall Computed Grades and Remarks:")
print("     ")

print(f"Final Marks: {finalmarks}")
print(f"Percentage: {percentage}%")
print(f"Overall Result: {result}")
print(f"Performance Remarks: {remarks}")
# Out:
# Input your Grades:
#
# Enter marks for Objected Oriented Programming: 85
# Enter marks for GEE: 75
# Enter marks for Mathematics In Modern World: 90
# Enter marks for Calculus: 20
# Enter marks for Physics: 20
#
# Grades:
#
# Objected Oriented Programming: 20.0 (Grade: A)
# GEE: 20.0 (Grade: B+)
# Mathematics In Modern World: 20.0 (Grade: A+)
# Calculus: 20.0 (Grade: F)
# Physics: 20.0 (Grade: F)
#
# Overall Computed Grades and Remarks:
#
# Final Marks: 290.0
# Percentage: 58.0%
# Overall Result:  Passed^-^
# Performance Remarks: Satisfactory
