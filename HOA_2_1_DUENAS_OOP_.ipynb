# %% [markdown]
# <a href="https://colab.research.google.com/github/qrfduenas-collab/CPE0091--OOP/blob/main/HOA_2_1_DUENAS_OOP_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon city Campus</center>
#
# ---
# <center><h4> Activity No. and Title:</h4></center>
#
# ---
# <center>
#
# | Course: CPE 009 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: Object Oriented Programming | **Date Performed:1/15/26** |
# | **Section**: CPE12S2 | **Date Submitted:1/15/26** |
# | **Student Name**:Duenas Ralph Florenz  | **Instructor's Name: Engr. Sayo** |
# </center>

# %% [markdown]
# **Objective/s of the activity:**
#
# 1.   Implement literals and variables in a python program.
#
#
# **Intended Learning Outcome:**
#
# 1.   Write a simple program implementing literals and variables.
# 2.   Use comments and identify keywords from identifiers created by users.
# **Discussion:**
#
# Discuss the use of variables, constants and literals in a python program.
#
#
# **Materials and Equipment:**
#
# 1.   List item
# 2.   List item
#
# **Procedure:**
#
# 1.   List item
# 2.   List item

# %%
# Place all the output of the procedures here

# %%
#PRELIM
PPHOA = float(input("Enter Hands-on Activity Grade: "))
PPQUIZ = float(input("Enter Prelim Quiz Grade: "))
PPAS = float(input("Enter Prelim Assignment Grade: "))
PPCS = (PPHOA * .5) + (PPQUIZ * .3) + (PPAS * .2)
PPEXAM = float(input("Enter Prelim Exam Grade: "))
PPGRADE = (PPEXAM * .5) + (PPCS * .5)
print("Prelim Grade:", round(PPGRADE, 2))

#MIDTERM
MMHOA = float(input("Enter Midterm Hands-on Activity Grade: "))
MMQUIZ = float(input("Enter Midterm Quiz Grade: "))
MMAS = float(input("Enter Midterm Assignment Grade: "))
MMCS = (MMHOA * .5) + (MMQUIZ * .3) + (MMAS * .2)
MMEXAM = float(input("Enter Midterm Exam Grade: "))
# FIXED: Changed MMGRADE to PPGRADE on the right side
MMGRADE = (PPGRADE * (1/3)) + (2/3) * ((MMEXAM * .5) + (MMCS * .5))
print("Midterm Grade:", round(MMGRADE, 2))

#FINAL
FFHOA = float(input("Enter Final Hands-on Activity Grade: "))
FFQUIZ = float(input("Enter Final Quiz Grade: "))
FFAS = float(input("Enter Final Assignment Grade: "))
FFCS = (FFHOA * .5) + (FFQUIZ * .3) + (FFAS * .2)
FFEXAM = float(input("Enter Final Exam Grade: "))
# FIXED: Changed FFGRADE to MMGRADE on the right side
FFGRADE = (MMGRADE * (1/3)) + (2/3) * ((FFEXAM * .5) + (FFCS * .5))
print("Final Grade:", round(FFGRADE, 2))
# Out:
# Enter Hands-on Activity Grade: 100
# Enter Prelim Quiz Grade: 85
# Enter Prelim Assignment Grade: 96
# Enter Prelim Exam Grade: 85
# Prelim Grade: 89.85
# Enter Midterm Hands-on Activity Grade: 85
# Enter Midterm Quiz Grade: 85
# Enter Midterm Assignment Grade: 96
# Enter Midterm Exam Grade: 100
# Midterm Grade: 92.35
# Enter Final Hands-on Activity Grade: 85
# Enter Final Quiz Grade: 100
# Enter Final Assignment Grade: 90
# Enter Final Exam Grade: 85
# Final Grade: 89.28

# %% [markdown]
# 1**Supplementary Activity**:
#
# 1.   List item
# 2.   List item

# %%
# Place all the output of the supplementary activity here

# %% [markdown]
# **Questions**: (write your answers in blue font color and questions in black)
#
# 1.   List item
# 2.   List item

# %% [markdown]
# **Conclusion**:
# (conclusion must be based from the objective and answers whether you attained the objective/s or not and a brief explanation how you attained it)

# %%
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)
PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)
# Out:
# Enter Hands-on Activity grade: 100
# Enter Prelim Quiz grade: 85
# Enter Prelim Assignment grade: 50
# Prelim CS is:  85.5
# Enter Prelim Exam grade: 75
# Prelim Grade is:  80.25
